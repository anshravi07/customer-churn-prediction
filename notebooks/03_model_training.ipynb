# %%
# !python src/preprocess.py
# !python src/train.py
# !python src/predict.py
# Out:
# python: can't open file 'c:\\Users\\anshr\\OneDrive\\Desktop\\Project\\Customer-Churn-Prediction\\notebooks\\src\\preprocess.py': [Errno 2] No such file or directory
# python: can't open file 'c:\\Users\\anshr\\OneDrive\\Desktop\\Project\\Customer-Churn-Prediction\\notebooks\\src\\train.py': [Errno 2] No such file or directory
# python: can't open file 'c:\\Users\\anshr\\OneDrive\\Desktop\\Project\\Customer-Churn-Prediction\\notebooks\\src\\predict.py': [Errno 2] No such file or directory
